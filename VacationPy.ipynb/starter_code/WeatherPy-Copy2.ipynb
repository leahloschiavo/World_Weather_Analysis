# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
#change the city everytime        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = []
        city_lng = []
        city_max_temp = []
        city_humidity = []
        city_clouds = []
        city_wind = []
        city_country = []
        city_date = []

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malindi
# Processing Record 2 of Set 1 | hafar al-batin
# Processing Record 3 of Set 1 | selfoss
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | havre
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | coahuayana de hidalgo
# Processing Record 8 of Set 1 | badger
# Processing Record 9 of Set 1 | port mathurin
# Processing Record 10 of Set 1 | papatowai
# Processing Record 11 of Set 1 | sao jose da coroa grande
# Processing Record 12 of Set 1 | bria
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | fernley
# Processing Record 16 of Set 1 | rabo de peixe
# Processing Record 17 of Set 1 | coronel suarez
# Processing Record 18 of Set 1 | bilibino
# Processing Record 19 of Set 1 | cargados carajos
# Processing Record 20 of Set 1 | wynyard
# Processing Record 21 of Set 1 | florina
# Processing Record 22 of Set 1 | guangyuan
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | enewetak
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | flying fish cove
# Processing Record 28 of Set 1 | conde
# Processing Record 29 of Set 1 | visby
# Processing Record 30 of Set 1 | adamstown
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | acapulco de juarez
# Processing Record 33 of Set 1 | stanley
# Processing Record 34 of Set 1 | amga
# Processing Record 35 of Set 1 | minas de marcona
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | puerto san carlos
# Processing Record 40 of Set 1 | melito di porto salvo
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | quellon
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | west island
# Processing Record 45 of Set 1 | khandyga
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | harur
# Processing Record 48 of Set 1 | khovd
# Processing Record 49 of Set 1 | iskateley
# Processing Record 50 of Set 1 | hamilton
# Processing Record 0 of Set 2 | geraldton
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | kerema
# Processing Record 3 of Set 2 | la passe
# Processing Record 4 of Set 2 | kuanda
# Processing Record 5 of Set 2 | vadso
# Processing Record 6 of Set 2 | iron river
# Processing Record 7 of Set 2 | sogndal
# Processing Record 8 of Set 2 | celestun
# Processing Record 9 of Set 2 | atafu village
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | huilong
# Processing Record 12 of Set 2 | grand rapids
# Processing Record 13 of Set 2 | masterton
# Processing Record 14 of Set 2 | haiku-pauwela
# Processing Record 15 of Set 2 | blama
# Processing Record 16 of Set 2 | wailua homesteads
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | suva
# Processing Record 19 of Set 2 | invercargill
# Processing Record 20 of Set 2 | susuman
# Processing Record 21 of Set 2 | portland
# Processing Record 22 of Set 2 | fale old settlement
# Processing Record 23 of Set 2 | uberaba
# Processing Record 24 of Set 2 | qaqortoq
# Processing Record 25 of Set 2 | ghat
# Processing Record 26 of Set 2 | dunedin
# Processing Record 27 of Set 2 | bodo
# Processing Record 28 of Set 2 | fort bragg
# Processing Record 29 of Set 2 | margaret river
# Processing Record 30 of Set 2 | tura
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | kodiak
# Processing Record 35 of Set 2 | edinburgh of the seven seas
# Processing Record 36 of Set 2 | labytnangi
# Processing Record 37 of Set 2 | ust-nera
# Processing Record 38 of Set 2 | langxiang
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | choyr
# Processing Record 42 of Set 2 | midvagur
# Processing Record 43 of Set 2 | st. john's
# Processing Record 44 of Set 2 | floro
# Processing Record 45 of Set 2 | bikenibeu village
# Processing Record 46 of Set 2 | zhezqazghan
# Processing Record 47 of Set 2 | porto novo
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | quepos
# Processing Record 0 of Set 3 | isafjordur
# Processing Record 1 of Set 3 | ringkobing
# Processing Record 2 of Set 3 | ta`u
# Processing Record 3 of Set 3 | flin flon
# Processing Record 4 of Set 3 | whitehorse
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | mirador
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | mount isa
# Processing Record 10 of Set 3 | puerto baquerizo moreno
# Processing Record 11 of Set 3 | kelso
# Processing Record 12 of Set 3 | utrik
# Processing Record 13 of Set 3 | velyka bahachka
# Processing Record 14 of Set 3 | vizinga
# Processing Record 15 of Set 3 | gao
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | falenki
# Processing Record 18 of Set 3 | concepcion
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | tazovsky
# Processing Record 21 of Set 3 | las vegas
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | aasiaat
# Processing Record 24 of Set 3 | berezovyy
# Processing Record 25 of Set 3 | island harbour
# Processing Record 26 of Set 3 | afaahiti
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | kapuskasing
# Processing Record 29 of Set 3 | marmaris
# Processing Record 30 of Set 3 | monchegorsk
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | sandnessjoen
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | tougan
# Processing Record 35 of Set 3 | lihue
# Processing Record 36 of Set 3 | sao joao da barra
# Processing Record 37 of Set 3 | smithers
# Processing Record 38 of Set 3 | nanao
# Processing Record 39 of Set 3 | makarov
# Processing Record 40 of Set 3 | charters towers
# Processing Record 41 of Set 3 | salida
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | neiafu
# Processing Record 44 of Set 3 | lander
# Processing Record 45 of Set 3 | olonkinbyen
# Processing Record 46 of Set 3 | saipan
# Processing Record 47 of Set 3 | newman
# Processing Record 48 of Set 3 | yoro
# Processing Record 49 of Set 3 | daru
# Processing Record 0 of Set 4 | taiohae
# Processing Record 1 of Set 4 | kangding
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | kurmuk
# Processing Record 4 of Set 4 | sihanoukville
# Processing Record 5 of Set 4 | palapag
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | bukama
# Processing Record 8 of Set 4 | al kharj
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | farafangana
# Processing Record 11 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 4 | al qadarif
# Processing Record 13 of Set 4 | noosa heads
# Processing Record 14 of Set 4 | kavaratti
# Processing Record 15 of Set 4 | sawang daen din
# Processing Record 16 of Set 4 | argo
# Processing Record 17 of Set 4 | malabar
# Processing Record 18 of Set 4 | alderetes
# Processing Record 19 of Set 4 | kalabo
# Processing Record 20 of Set 4 | zangguy
# Processing Record 21 of Set 4 | konarka
# Processing Record 22 of Set 4 | natal
# Processing Record 23 of Set 4 | vilyuchinsk
# Processing Record 24 of Set 4 | udachny
# Processing Record 25 of Set 4 | punta arenas
# Processing Record 26 of Set 4 | port douglas
# Processing Record 27 of Set 4 | shingu
# Processing Record 28 of Set 4 | howrah
# Processing Record 29 of Set 4 | belawan
# Processing Record 30 of Set 4 | yarmouth
# Processing Record 31 of Set 4 | ocean pointe
# Processing Record 32 of Set 4 | vorgashor
# Processing Record 33 of Set 4 | xinyuan
# Processing Record 34 of Set 4 | nar'yan-mar
# Processing Record 35 of Set 4 | constantia
# Processing Record 36 of Set 4 | fort st. john
# Processing Record 37 of Set 4 | loiza
# Processing Record 38 of Set 4 | copiapo
# Processing Record 39 of Set 4 | nikolayevsk-on-amure
# Processing Record 40 of Set 4 | freetown
# Processing Record 41 of Set 4 | espargos
# Processing Record 42 of Set 4 | ha'il
# Processing Record 43 of Set 4 | the pas
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | vernon
# Processing Record 47 of Set 4 | avon
# Processing Record 48 of Set 4 | kingston
# Processing Record 49 of Set 4 | lhuentse
# Processing Record 0 of Set 5 | benito garcia (el zorrillo)
# Processing Record 1 of Set 5 | villa del campo
# Processing Record 2 of Set 5 | camalu
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | usinsk
# Processing Record 5 of Set 5 | bathurst city centre
# Processing Record 6 of Set 5 | bako
# Processing Record 7 of Set 5 | oral
# Processing Record 8 of Set 5 | yangor
# Processing Record 9 of Set 5 | ola
# Processing Record 10 of Set 5 | saudarkrokur
# Processing Record 11 of Set 5 | merizo village
# Processing Record 12 of Set 5 | douentza
# Processing Record 13 of Set 5 | chuhar jamali
# Processing Record 14 of Set 5 | victorica
# Processing Record 15 of Set 5 | hayma'
# Processing Record 16 of Set 5 | tual
# Processing Record 17 of Set 5 | rikaze
# Processing Record 18 of Set 5 | holualoa
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | ad dilam
# Processing Record 21 of Set 5 | hounde
# Processing Record 22 of Set 5 | tosontsengel
# Processing Record 23 of Set 5 | naha
# Processing Record 24 of Set 5 | vingt cinq
# Processing Record 25 of Set 5 | ouellah
# Processing Record 26 of Set 5 | taradale
# Processing Record 27 of Set 5 | egersund
# Processing Record 28 of Set 5 | nuuk
# Processing Record 29 of Set 5 | sinabang
# Processing Record 30 of Set 5 | viligili
# Processing Record 31 of Set 5 | fada
# Processing Record 32 of Set 5 | puerto deseado
# Processing Record 33 of Set 5 | miguel ahumada
# Processing Record 34 of Set 5 | valdivia
# Processing Record 35 of Set 5 | ishim
# Processing Record 36 of Set 5 | tralee
# Processing Record 37 of Set 5 | san antonio de pale
# Processing Record 38 of Set 5 | itoman
# Processing Record 39 of Set 5 | colonia
# Processing Record 40 of Set 5 | hadibu
# Processing Record 41 of Set 5 | geneina
# Processing Record 42 of Set 5 | nema
# Processing Record 43 of Set 5 | arauco
# Processing Record 44 of Set 5 | thabazimbi
# Processing Record 45 of Set 5 | camana
# Processing Record 46 of Set 5 | san fernando
# Processing Record 47 of Set 5 | takasaki
# Processing Record 48 of Set 5 | sao felix do xingu
# Processing Record 49 of Set 5 | kalmunai
# Processing Record 0 of Set 6 | port saint john's
# Processing Record 1 of Set 6 | labrador city
# Processing Record 2 of Set 6 | trairi
# Processing Record 3 of Set 6 | san antonio del estrecho
# Processing Record 4 of Set 6 | malango
# Processing Record 5 of Set 6 | toliara
# Processing Record 6 of Set 6 | weno
# Processing Record 7 of Set 6 | fumel
# Processing Record 8 of Set 6 | vrnograc
# Processing Record 9 of Set 6 | dryden
# Processing Record 10 of Set 6 | benguela
# Processing Record 11 of Set 6 | cuatro cienegas de carranza
# Processing Record 12 of Set 6 | muana
# Processing Record 13 of Set 6 | lubao
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | pont rouge
# Processing Record 16 of Set 6 | serowe
# Processing Record 17 of Set 6 | alausi
# Processing Record 18 of Set 6 | gondal
# Processing Record 19 of Set 6 | taroudant
# Processing Record 20 of Set 6 | chegdomyn
# Processing Record 21 of Set 6 | thandla
# Processing Record 22 of Set 6 | chokwe
# Processing Record 23 of Set 6 | armacao de buzios
# Processing Record 24 of Set 6 | talacogon
# Processing Record 25 of Set 6 | port augusta
# Processing Record 26 of Set 6 | berryville
# Processing Record 27 of Set 6 | pacific grove
# Processing Record 28 of Set 6 | klyuchi
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | esperanza
# Processing Record 31 of Set 6 | umm kaddadah
# Processing Record 32 of Set 6 | sakaraha
# Processing Record 33 of Set 6 | antalaha
# Processing Record 34 of Set 6 | kenora
# Processing Record 35 of Set 6 | jackson
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | tazacorte
# Processing Record 38 of Set 6 | tolanaro
# Processing Record 39 of Set 6 | palikir - national government center
# Processing Record 40 of Set 6 | ar rutbah
# Processing Record 41 of Set 6 | barakani
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | san luis de la loma
# Processing Record 44 of Set 6 | puerto ayora
# Processing Record 45 of Set 6 | okha
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | woodward
# Processing Record 48 of Set 6 | lazaro cardenas
# Processing Record 49 of Set 6 | hawaiian paradise park
# Processing Record 0 of Set 7 | det udom
# Processing Record 1 of Set 7 | polyarnyy
# Processing Record 2 of Set 7 | mil'kovo
# Processing Record 3 of Set 7 | roma
# Processing Record 4 of Set 7 | montes claros
# Processing Record 5 of Set 7 | luwuk
# Processing Record 6 of Set 7 | paradip garh
# Processing Record 7 of Set 7 | sao cristovao
# Processing Record 8 of Set 7 | seogwipo
# Processing Record 9 of Set 7 | anadyr
# Processing Record 10 of Set 7 | grand falls-windsor
# Processing Record 11 of Set 7 | checker hall
# Processing Record 12 of Set 7 | antonio enes
# Processing Record 13 of Set 7 | chita
# Processing Record 14 of Set 7 | mersin
# Processing Record 15 of Set 7 | guachochi
# Processing Record 16 of Set 7 | san jose
# Processing Record 17 of Set 7 | tonghae
# Processing Record 18 of Set 7 | xinzhi
# Processing Record 19 of Set 7 | filadelfia
# Processing Record 20 of Set 7 | bandrele
# Processing Record 21 of Set 7 | gobabis
# Processing Record 22 of Set 7 | tchintabaraden
# Processing Record 23 of Set 7 | almeirim
# Processing Record 24 of Set 7 | torghay
# Processing Record 25 of Set 7 | villa gesell
# Processing Record 26 of Set 7 | westport
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | kidal
# Processing Record 29 of Set 7 | baskale
# Processing Record 30 of Set 7 | el granada
# Processing Record 31 of Set 7 | letterkenny
# Processing Record 32 of Set 7 | funafuti
# Processing Record 33 of Set 7 | sebin karahisar
# Processing Record 34 of Set 7 | eyl
# Processing Record 35 of Set 7 | clarksburg
# Processing Record 36 of Set 7 | rong'an
# Processing Record 37 of Set 7 | baruun-urt
# Processing Record 38 of Set 7 | usogorsk
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | kingscliff
# Processing Record 41 of Set 7 | el calafate
# Processing Record 42 of Set 7 | inari
# Processing Record 43 of Set 7 | coquimbo
# Processing Record 44 of Set 7 | chifeng
# Processing Record 45 of Set 7 | yingchuan
# Processing Record 46 of Set 7 | lincheng
# Processing Record 47 of Set 7 | kakamega
# Processing Record 48 of Set 7 | marang
# Processing Record 49 of Set 7 | vilyuysk
# Processing Record 0 of Set 8 | nabire
# Processing Record 1 of Set 8 | khenifra
# Processing Record 2 of Set 8 | iwanai
# Processing Record 3 of Set 8 | bambari
# Processing Record 4 of Set 8 | vila velha
# Processing Record 5 of Set 8 | vila franca do campo
# Processing Record 6 of Set 8 | viedma
# Processing Record 7 of Set 8 | katsuura
# Processing Record 8 of Set 8 | zaozersk
# Processing Record 9 of Set 8 | yung shue wan
# Processing Record 10 of Set 8 | mahina
# Processing Record 11 of Set 8 | elek
# Processing Record 12 of Set 8 | sinop
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | lashio
# Processing Record 15 of Set 8 | manatutu
# Processing Record 16 of Set 8 | mangrol
# Processing Record 17 of Set 8 | smirnykh
# Processing Record 18 of Set 8 | shiraz
# Processing Record 19 of Set 8 | kosh-agach
# Processing Record 20 of Set 8 | tofol
# Processing Record 21 of Set 8 | alvesta
# Processing Record 22 of Set 8 | churapcha
# Processing Record 23 of Set 8 | shar'ya
# Processing Record 24 of Set 8 | toga village
# Processing Record 25 of Set 8 | ahau
# Processing Record 26 of Set 8 | viana do castelo
# Processing Record 27 of Set 8 | grootfontein
# Processing Record 28 of Set 8 | barra de santo antonio
# Processing Record 29 of Set 8 | luena
# Processing Record 30 of Set 8 | emerald
# Processing Record 31 of Set 8 | saint-valery-en-caux
# Processing Record 32 of Set 8 | sinan
# Processing Record 33 of Set 8 | thurso
# Processing Record 34 of Set 8 | nova vicosa
# Processing Record 35 of Set 8 | voznesenskoye
# Processing Record 36 of Set 8 | shimoda
# Processing Record 37 of Set 8 | mar del plata
# Processing Record 38 of Set 8 | yamada
# Processing Record 39 of Set 8 | bhamo
# Processing Record 40 of Set 8 | moires
# Processing Record 41 of Set 8 | uturoa
# Processing Record 42 of Set 8 | borogontsy
# Processing Record 43 of Set 8 | balabac
# Processing Record 44 of Set 8 | tirumullaivasal
# Processing Record 45 of Set 8 | tateyama
# Processing Record 46 of Set 8 | nadym
# Processing Record 47 of Set 8 | sambava
# Processing Record 48 of Set 8 | las tablas
# Processing Record 49 of Set 8 | tromso
# Processing Record 0 of Set 9 | dali
# Processing Record 1 of Set 9 | kandahar
# Processing Record 2 of Set 9 | cobija
# Processing Record 3 of Set 9 | keflavik
# Processing Record 4 of Set 9 | codrington
# Processing Record 5 of Set 9 | pokhara
# Processing Record 6 of Set 9 | northam
# Processing Record 7 of Set 9 | chibougamau
# Processing Record 8 of Set 9 | guerrero negro
# Processing Record 9 of Set 9 | puerto lempira
# Processing Record 10 of Set 9 | la'ie
# Processing Record 11 of Set 9 | nadvoitsy
# Processing Record 12 of Set 9 | ancud
# Processing Record 13 of Set 9 | muskogee
# Processing Record 14 of Set 9 | oualidia
# Processing Record 15 of Set 9 | mihail kogalniceanu
# Processing Record 16 of Set 9 | acarau
# Processing Record 17 of Set 9 | nurabad
# Processing Record 18 of Set 9 | bwizibwera
# Processing Record 19 of Set 9 | tucurui
# Processing Record 20 of Set 9 | midland
# Processing Record 21 of Set 9 | khandud
# Processing Record 22 of Set 9 | yaren
# Processing Record 23 of Set 9 | calama
# Processing Record 24 of Set 9 | azhikkal
# Processing Record 25 of Set 9 | asau
# Processing Record 26 of Set 9 | esperalvillo
# Processing Record 27 of Set 9 | banjar
# Processing Record 28 of Set 9 | ceres
# Processing Record 29 of Set 9 | fuvahmulah
# Processing Record 30 of Set 9 | harlingen
# Processing Record 31 of Set 9 | sechura
# Processing Record 32 of Set 9 | bargaal
# Processing Record 33 of Set 9 | saldarriaga
# Processing Record 34 of Set 9 | magione
# Processing Record 35 of Set 9 | cachoeiras de macacu
# Processing Record 36 of Set 9 | binagadi
# Processing Record 37 of Set 9 | asbury park
# Processing Record 38 of Set 9 | castillos
# Processing Record 39 of Set 9 | turkmenbasy
# Processing Record 40 of Set 9 | piacabucu
# Processing Record 41 of Set 9 | saldanha
# Processing Record 42 of Set 9 | valparaiso
# Processing Record 43 of Set 9 | happy valley-goose bay
# Processing Record 44 of Set 9 | naze
# Processing Record 45 of Set 9 | dili
# Processing Record 46 of Set 9 | remire-montjoly
# Processing Record 47 of Set 9 | wysokie mazowieckie
# Processing Record 48 of Set 9 | sturgeon bay
# Processing Record 49 of Set 9 | lata
# Processing Record 0 of Set 10 | kalifornsky
# Processing Record 1 of Set 10 | newala kisimani
# Processing Record 2 of Set 10 | hardys memories of africa
# Processing Record 3 of Set 10 | rethymno
# Processing Record 4 of Set 10 | fort mcmurray
# Processing Record 5 of Set 10 | porto santo stefano
# Processing Record 6 of Set 10 | 'ohonua
# Processing Record 7 of Set 10 | akonolinga
# Processing Record 8 of Set 10 | peniche
# Processing Record 9 of Set 10 | todos santos
# Processing Record 10 of Set 10 | salina cruz
# Processing Record 11 of Set 10 | murwara
# Processing Record 12 of Set 10 | buala
# Processing Record 13 of Set 10 | den burg
# Processing Record 14 of Set 10 | chala
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | cidreira
# Processing Record 17 of Set 10 | oyem
# Processing Record 18 of Set 10 | paulden
# Processing Record 19 of Set 10 | opuwo
# Processing Record 20 of Set 10 | mazan
# Processing Record 21 of Set 10 | rodolfo sanchez taboada
# Processing Record 22 of Set 10 | salyan
# Processing Record 23 of Set 10 | lyskovo
# Processing Record 24 of Set 10 | nyaunglebin
# Processing Record 25 of Set 10 | igarka
# Processing Record 26 of Set 10 | chernyshevskiy
# Processing Record 27 of Set 10 | parambu
# Processing Record 28 of Set 10 | mamuju
# Processing Record 29 of Set 10 | rajaori
# Processing Record 30 of Set 10 | pisco
# Processing Record 31 of Set 10 | ceeldheer
# Processing Record 32 of Set 10 | dawei
# Processing Record 33 of Set 10 | saint-philippe
# Processing Record 34 of Set 10 | moultonborough
# Processing Record 35 of Set 10 | kamina
# Processing Record 36 of Set 10 | isle of lewis
# Processing Record 37 of Set 10 | kimbo
# Processing Record 38 of Set 10 | wajir
# Processing Record 39 of Set 10 | dolores
# Processing Record 40 of Set 10 | marco island
# Processing Record 41 of Set 10 | auch
# Processing Record 42 of Set 10 | rawson
# Processing Record 43 of Set 10 | yunak
# Processing Record 44 of Set 10 | gurupa
# Processing Record 45 of Set 10 | camiri
# Processing Record 46 of Set 10 | arco
# Processing Record 47 of Set 10 | saratamata
# Processing Record 48 of Set 10 | villa de san antonio
# Processing Record 49 of Set 10 | bengkulu
# Processing Record 0 of Set 11 | ust'-barguzin
# Processing Record 1 of Set 11 | antigonish
# Processing Record 2 of Set 11 | bondoukou
# Processing Record 3 of Set 11 | new norfolk
# Processing Record 4 of Set 11 | grand gaube
# Processing Record 5 of Set 11 | auki
# Processing Record 6 of Set 11 | tomatlan
# Processing Record 7 of Set 11 | akureyri
# Processing Record 8 of Set 11 | uttarkashi
# Processing Record 9 of Set 11 | dudinka
# Processing Record 10 of Set 11 | rabaul
# Processing Record 11 of Set 11 | iquique
# Processing Record 12 of Set 11 | sirte
# Processing Record 13 of Set 11 | gamba
# Processing Record 14 of Set 11 | santa maria del oro
# Processing Record 15 of Set 11 | al jawf
# Processing Record 16 of Set 11 | george
# Processing Record 17 of Set 11 | san pedro pochutla
# Processing Record 18 of Set 11 | ust'-ordynskiy
# Processing Record 19 of Set 11 | kulgam
# Processing Record 20 of Set 11 | xilin hot
# Processing Record 21 of Set 11 | constitucion
# Processing Record 22 of Set 11 | aykhal
# Processing Record 23 of Set 11 | rongelap
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | paphos
# Processing Record 26 of Set 11 | mount pearl
# Processing Record 27 of Set 11 | cromwell
# Processing Record 28 of Set 11 | kampong chhnang
# Processing Record 29 of Set 11 | mohammedia
# Processing Record 30 of Set 11 | kaitong
# Processing Record 31 of Set 11 | benghazi
# Processing Record 32 of Set 11 | devonport
# Processing Record 33 of Set 11 | malinyi
# Processing Record 34 of Set 11 | ulsteinvik
# Processing Record 35 of Set 11 | prieska
# Processing Record 36 of Set 11 | madimba
# Processing Record 37 of Set 11 | umba
# Processing Record 38 of Set 11 | victoria
# Processing Record 39 of Set 11 | taft
# Processing Record 40 of Set 11 | formosa
# Processing Record 41 of Set 11 | phan thiet
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | yalihuyuk
# Processing Record 44 of Set 11 | rio grande
# Processing Record 45 of Set 11 | hammerfest
# Processing Record 46 of Set 11 | mandalgovi
# Processing Record 47 of Set 11 | arvayheer
# Processing Record 48 of Set 11 | shache
# Processing Record 49 of Set 11 | medina
# Processing Record 0 of Set 12 | yuzhno-kurilsk
# Processing Record 1 of Set 12 | bodaybo
# Processing Record 2 of Set 12 | obihiro
# Processing Record 3 of Set 12 | taroa
# Processing Record 4 of Set 12 | kulhudhuffushi
# Processing Record 5 of Set 12 | esmeraldas
# Processing Record 6 of Set 12 | chonchi
# Processing Record 7 of Set 12 | cidade velha
# Processing Record 8 of Set 12 | shwebo
# Processing Record 9 of Set 12 | port blair
# Processing Record 10 of Set 12 | tekkali
# Processing Record 11 of Set 12 | shangri-la
# Processing Record 12 of Set 12 | dubbo
# Processing Record 13 of Set 12 | ambovombe
# Processing Record 14 of Set 12 | acajutla
# Processing Record 15 of Set 12 | beyneu
# Processing Record 16 of Set 12 | vallenar
# Processing Record 17 of Set 12 | ravar
# Processing Record 18 of Set 12 | tadine
# Processing Record 19 of Set 12 | huescar
# Processing Record 20 of Set 12 | karatas
# Processing Record 21 of Set 12 | cudillero
# Processing Record 22 of Set 12 | eravur town
# Processing Record 23 of Set 12 | ghadamis
# Processing Record 24 of Set 12 | mary
# Processing Record 25 of Set 12 | puerto colombia
# Processing Record 26 of Set 12 | hudiksvall
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | vanino
# Processing Record 29 of Set 12 | arteche
# Processing Record 30 of Set 12 | majie
# Processing Record 31 of Set 12 | tara
# Processing Record 32 of Set 12 | harper
# Processing Record 33 of Set 12 | kangaba
# Processing Record 34 of Set 12 | playa del ingles
# Processing Record 35 of Set 12 | mitsamiouli
# Processing Record 36 of Set 12 | bela vista de goias
# Processing Record 37 of Set 12 | hulan ergi
# Processing Record 38 of Set 12 | fortuna foothills
# Processing Record 39 of Set 12 | aral
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_weather_df = city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# Show Record Count
city_weather_df

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")
# Incorporate the other graph properties
plt.title("Lat vs. Temp")
plt.ylabel("Temp (Celsius)")
plt.xlabel("Lat")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")


# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(regress_values)

# LL is this the function?

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_data = {
    "city": cities,
    "lat": lat,
    "max_temp": temp
    "humidity": humi
    "Cloudiness": cloudy
    "Wind Speed": Wind
    "Country" : location
    "Date": date
}

# Display sample data
northern_hemi_df.head()

# LL check to make sure you're doing dataframe correctly

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_data = {
    "City_ID": ID
    "city": cities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Display sample data
southern_hemi_df.head()

#LL need to finish dataframe

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(regress_values)

#LL look at linear regression

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(regress_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#LL - plots to create
#Northern Hemisphere: Temperature vs. Latitude

#Southern Hemisphere: Temperature vs. Latitude

#Northern Hemisphere: Humidity vs. Latitude

#Southern Hemisphere: Humidity vs. Latitude

#Northern Hemisphere: Cloudiness vs. Latitude

#Southern Hemisphere: Cloudiness vs. Latitude

#Northern Hemisphere: Wind Speed vs. Latitude

#Southern Hemisphere: Wind Speed vs. Latitude
